# %%
import os

# %%
os.getcwd()
# Out:
# "c:\\Users\\Aliya\\OneDrive\\Desktop\\aliya's python"

# %%
files = os.listdir()
print(files)
# Out:
# ['.git', '.gitattributes', '.ipynb_checkpoints', 'basics.ipynb', 'Downloads - Shortcut.lnk', 'example1.py', 'example10.py', 'example11.py', 'example12.py', 'example13.py', 'example2.py', 'example3.py', 'example4.py', 'example5.py', 'example8.py', 'example9.py', 'file_handling.ipynb', 'Git Bash.lnk', 'GitHub Desktop.lnk', 'info.txt', 'kahani1.txt', 'list.ipynb', 'loops.ipynb', 'loops2.ipynb', 'os_module.ipynb', 'pythonstrings.ipynb', 'string-DESKTOP-ED0HS3P.ipynb', 'string.ipynb', 'string_assignment.ipynb', 'tuple.ipynb', 'Visual Studio Code.lnk']

# %%
filesX = os.listdir('c:/windows/system32/')

# %%
len(filesX)
# Out:
# 4373

# %%
dlls = 0
for file in filesX:
    if file.endswith('.dll'):
        dlls += 1
print(f'the system has {dlls} dlls')
# Out:
# the system has 3013 dlls

# %%
os.mkdir('basics')

# %%
os.rmdir('basics')

# %%
os.path.isdir('.ipynb_checkpoints')
# Out:
# True

# %%
for item in files:
    if os.path.isdir(item):
        print(f'{item} is directory')
# Out:
# .git is directory
# .ipynb_checkpoints is directory

# %%
sizeofVS = os.path.getsize(r'C:\Users\Aliya\Downloads\VSCodeUserSetup-x64-1.67.2.exe')
print(sizeofVS)
# Out:
# 79513464

# %%
#converting bytes to mb
sizeofVS/(1024*1024)
# Out:
# 75.82994842529297

# %%
files = os.listdir

# %%
os.path.isdir('.ipynb_checkpoint');

# %%
folder = 'C:/windows/system32/'
files =os.listdir(folder)
for item in files:
    fullpath = os.path.join(folder,item)
    if os.path.isfile(fullpath):
        sz =os.path.getsize(fullpath)
        print(f'{item.ljust(70)} | {sz/1024 :.1f} kb')
# Out:
# 69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll               | 11.8 kb
# 6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll          | 12.9 kb
# @AdvancedKeySettingsNotification.png                                   | 3.1 kb
# @AppHelpToast.png                                                      | 0.2 kb
# @AudioToastIcon.png                                                    | 0.3 kb
# @BackgroundAccessToastIcon.png                                         | 0.4 kb
# @bitlockertoastimage.png                                               | 0.2 kb
# @edptoastimage.png                                                     | 14.4 kb
# @EnrollmentToastIcon.png                                               | 0.3 kb
# @language_notification_icon.png                                        | 0.5 kb
# @optionalfeatures.png                                                  | 0.5 kb
# @StorageSenseToastIcon.png                                             | 0.3 kb
# ...
